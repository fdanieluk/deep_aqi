# %%
from os.path import join
import pandas as pd
import seaborn as sns
import warnings

import pymc3 as pm

from sklearn.metrics import mean_absolute_error, median_absolute_error, mean_squared_error, r2_score
from sklearn.model_selection import train_test_split, RandomizedSearchCV, GridSearchCV
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler
from sklearn.pipeline import make_pipeline, Pipeline
from sklearn.tree import DecisionTreeRegressor


from deep_aqi import ROOT


pd.set_option('expand_frame_repr', False)
pd.set_option('max_columns', 50)
pd.set_option('max_rows', 25)
pd.options.mode.chained_assignment = None

# %%
# warnings.filterwarnings("ignore")

# %%
def show_result(results):
    print(results.describe())
    results = results.reset_index()
    results = results.melt(id_vars='index', value_vars=['MAE', 'MSE', 'MdAE', 'R2'])
    results = results.loc[results.variable != 'MSE', :]
    
    sns.boxplot(x=results['variable'], y=results['value'])

# %%
PROCESSED_DATA = join(ROOT, 'data', 'processed')
INTERIM_DATA = join(ROOT, 'data', 'interim')
RAW_DATA = join(ROOT, 'data', 'raw')

# %%
file_path = join(PROCESSED_DATA, '88101.parquet')

data_source = pd.read_parquet(file_path)
target_column = data_source.columns[-1]

# %%
focus_stations = data_source.SiteCode.value_counts()[:4].index
data_source = data_source.loc[data_source.SiteCode.isin(focus_stations), :]
data_source.head()
# Out:
#                              SiteCode           LocalDate  WindDir  WindSpeed  Temperature  Pressure  RelHum  PM2.5 - Local Conditions
# index
# 4125   Louisiana_East Baton Rouge_9.0 2014-01-01 04:00:00    116.0   6.804044     7.222222  101700.0    97.0                      23.0
# 4126   Louisiana_East Baton Rouge_9.0 2014-01-02 07:00:00    310.0  11.858476    13.333333  100900.0    99.0                       9.8
# 4127   Louisiana_East Baton Rouge_9.0 2014-01-03 13:00:00     60.0   6.804044     6.666667  102100.0    32.0                       5.7
# 4128   Louisiana_East Baton Rouge_9.0 2014-01-04 02:00:00    294.0   1.749611     0.000000  101600.0    74.0                       6.6
# 4129   Louisiana_East Baton Rouge_9.0 2014-01-04 04:00:00    276.0  13.413686    -1.111111  101600.0    74.0                      10.1

# %%
def simple_linear_1(data_source):
    to_concat = []
    for site_code, df in data_source.groupby(by='SiteCode'):

        X = df.loc[:, ['WindDir', 'WindSpeed', 'Temperature', 'Pressure', 'RelHum']]
        Y = df.loc[:, target_column]

        X_train, X_test, y_train, y_test = train_test_split(X, Y, random_state=23)

        model = LinearRegression()

        model.fit(X_train, y_train)


        y_pred = model.predict(X_test)


        mae = mean_absolute_error(y_test, y_pred)
        mse = mean_squared_error(y_test, y_pred)
        mdae = median_absolute_error(y_test, y_pred)
        r2 = r2_score(y_test, y_pred)

        mean = np.mean(df[df.columns[-1]])

        result = pd.DataFrame(index = [site_code],
                              data={'MAE': mae,
                                    'MSE': mse,
                                    'MdAE': mdae,
                                    'R2': r2,
                                    'MEAN': mean,
                                   })
        to_concat.append(result)

    return pd.concat(to_concat)

# %%
data_source
# Out:
#                               SiteCode           LocalDate  WindDir  WindSpeed  Temperature  Pressure  RelHum  PM2.5 - Local Conditions
# index
# 4125    Louisiana_East Baton Rouge_9.0 2014-01-01 04:00:00    116.0   6.804044     7.222222  101700.0    97.0                      23.0
# 4126    Louisiana_East Baton Rouge_9.0 2014-01-02 07:00:00    310.0  11.858476    13.333333  100900.0    99.0                       9.8
# 4127    Louisiana_East Baton Rouge_9.0 2014-01-03 13:00:00     60.0   6.804044     6.666667  102100.0    32.0                       5.7
# 4128    Louisiana_East Baton Rouge_9.0 2014-01-04 02:00:00    294.0   1.749611     0.000000  101600.0    74.0                       6.6
# 4129    Louisiana_East Baton Rouge_9.0 2014-01-04 04:00:00    276.0  13.413686    -1.111111  101600.0    74.0                      10.1
# 4130    Louisiana_East Baton Rouge_9.0 2014-01-04 21:00:00    129.0  10.108865    10.000000  101000.0    94.0                      16.4
# 4131    Louisiana_East Baton Rouge_9.0 2014-01-05 15:00:00    293.0  16.912908    16.666667  100400.0    91.0                       0.5
# 4132    Louisiana_East Baton Rouge_9.0 2014-01-06 07:00:00    355.0  20.217729    -2.777778  102500.0    67.0                       5.3
# 4133    Louisiana_East Baton Rouge_9.0 2014-01-06 09:00:00    353.0  16.912908    -2.222222  102800.0    58.0                       5.2
# 4134    Louisiana_East Baton Rouge_9.0 2014-01-06 12:00:00    323.0  15.163297     0.555556  102600.0    36.0                       5.7
# 4135    Louisiana_East Baton Rouge_9.0 2014-01-06 16:00:00    327.0  15.163297    -1.666667  102700.0    34.0                       7.2
# 4136    Louisiana_East Baton Rouge_9.0 2014-01-07 04:00:00     19.0   8.359253    -3.888889  102900.0    38.0                       5.1
# ...                                ...                 ...      ...        ...          ...       ...     ...                       ...
# 189320          North Dakota_Burke_4.0 2015-12-26 04:00:00    309.0   0.972006   -23.888889   94790.0    69.0                       6.5
# 189321          North Dakota_Burke_4.0 2015-12-26 13:00:00    230.0  26.827372   -16.111111   94790.0    76.0                       6.6
# 189322          North Dakota_Burke_4.0 2015-12-27 09:00:00    158.0   6.220840   -21.111111   94660.0    72.0                      10.5
# 189323          North Dakota_Burke_4.0 2015-12-27 12:00:00    182.0  27.021773   -15.000000   94390.0    77.0                       8.8
# 189324          North Dakota_Burke_4.0 2015-12-28 16:00:00    161.0  15.163297   -10.555556   93060.0    76.0                       9.7
# 189325          North Dakota_Burke_4.0 2015-12-29 14:00:00     39.0   6.998445   -13.888889   93590.0    78.0                      12.1
# 189326          North Dakota_Burke_4.0 2015-12-30 07:00:00    264.0   8.553655   -16.111111   93720.0    76.0                      11.8
# 189327          North Dakota_Burke_4.0 2015-12-30 15:00:00    280.0  19.634526   -11.666667   93590.0    72.0                      12.9
# 189328          North Dakota_Burke_4.0 2015-12-30 21:00:00    271.0  19.634526   -11.666667   93590.0    76.0                       9.4
# 189329          North Dakota_Burke_4.0 2015-12-31 07:00:00    282.0  27.216174   -12.777778   93720.0    77.0                       9.2
# 189330          North Dakota_Burke_4.0 2015-12-31 16:00:00    271.0  33.048212    -5.555556   93860.0    71.0                       3.7
# 189331          North Dakota_Burke_4.0 2015-12-31 23:00:00    255.0  47.628305    -6.666667   93320.0    69.0                       8.0
#
# [224045 rows x 8 columns]

# %%
data_source.columns
# Out:
# Index(['SiteCode', 'LocalDate', 'WindDir', 'WindSpeed', 'Temperature',
#        'Pressure', 'RelHum', 'PM2.5 - Local Conditions'],
#       dtype='object')

# %%
df = data_source

# %%
with pm.Model() as unpooled_model:


    a = pm.Normal('a', 0, sd=100, shape=1)
    b = pm.Normal('b', 0, sd=100, shape=1)
    c = pm.Normal('c', 0, sd=100, shape=1)
#     d = pm.Normal('d', 0, sd=100, shape=1)
#     e = pm.Normal('e', 0, sd=100, shape=1)
#     f = pm.Normal('f', 0, sd=100, shape=1)


    eps = pm.HalfCauchy('eps', 5)

    y_hat = a + b*df.WindDir + c*df.WindSpeed #+ d*df.Temperature + e*df.Pressure + f*df.RelHum

    # Data likelihood
    y = pm.Normal('y', y_hat, sd=eps, observed=data_source[target_column])

# %%
with unpooled_model:
    unpooled_trace = pm.sample(100, threads=4)
# Out:
# WARNING:pymc3:Only 100 samples in chain.
#
# Sampling 2 chains:   0%|          | 0/1200 [00:00<?, ?draws/s]
# Sampling 2 chains:   1%|          | 13/1200 [00:00<00:09, 122.99draws/s]
# Sampling 2 chains:   2%|▏         | 23/1200 [00:00<00:10, 114.93draws/s]
# Sampling 2 chains:   3%|▎         | 31/1200 [00:00<00:11, 99.14draws/s]
# Sampling 2 chains:   3%|▎         | 38/1200 [00:00<00:14, 82.00draws/s]
# Sampling 2 chains:   4%|▍         | 46/1200 [00:00<00:14, 77.71draws/s]
# Sampling 2 chains:   5%|▍         | 55/1200 [00:00<00:14, 79.42draws/s]
# Sampling 2 chains:   6%|▌         | 67/1200 [00:00<00:12, 87.98draws/s]
# Sampling 2 chains:   6%|▋         | 77/1200 [00:00<00:13, 85.75draws/s]
# Sampling 2 chains:   7%|▋         | 87/1200 [00:00<00:12, 88.37draws/s]
# Sampling 2 chains:   8%|▊         | 96/1200 [00:01<00:13, 83.98draws/s]
# Sampling 2 chains:   9%|▉         | 105/1200 [00:01<00:13, 81.23draws/s]
# Sampling 2 chains:  10%|▉         | 117/1200 [00:01<00:12, 88.21draws/s]
# Sampling 2 chains:  10%|█         | 126/1200 [00:01<00:16, 67.12draws/s]
# Sampling 2 chains:  11%|█         | 134/1200 [00:01<00:15, 68.66draws/s]
# Sampling 2 chains:  12%|█▏        | 142/1200 [00:01<00:14, 71.39draws/s]
# Sampling 2 chains:  13%|█▎        | 151/1200 [00:01<00:14, 72.38draws/s]
# Sampling 2 chains:  13%|█▎        | 159/1200 [00:02<00:15, 68.28draws/s]
# Sampling 2 chains:  14%|█▍        | 167/1200 [00:02<00:16, 62.11draws/s]
# Sampling 2 chains:  14%|█▍        | 174/1200 [00:02<00:17, 59.84draws/s]
# Sampling 2 chains:  15%|█▌        | 182/1200 [00:02<00:15, 64.54draws/s]
# Sampling 2 chains:  16%|█▌        | 189/1200 [00:02<00:15, 65.48draws/s]
# Sampling 2 chains:  16%|█▋        | 196/1200 [00:02<00:16, 59.85draws/s]
# Sampling 2 chains:  17%|█▋        | 207/1200 [00:02<00:14, 67.70draws/s]
# Sampling 2 chains:  18%|█▊        | 215/1200 [00:02<00:13, 70.55draws/s]
# Sampling 2 chains:  19%|█▊        | 224/1200 [00:02<00:13, 73.42draws/s]
# Sampling 2 chains:  19%|█▉        | 232/1200 [00:03<00:12, 74.72draws/s]
# Sampling 2 chains:  20%|██        | 240/1200 [00:03<00:15, 62.67draws/s]
# Sampling 2 chains:  21%|██        | 247/1200 [00:03<00:15, 61.64draws/s]
# Sampling 2 chains:  21%|██        | 254/1200 [00:03<00:15, 60.05draws/s]
# Sampling 2 chains:  22%|██▏       | 261/1200 [00:03<00:16, 56.36draws/s]
# Sampling 2 chains:  22%|██▏       | 269/1200 [00:03<00:15, 60.53draws/s]
# Sampling 2 chains:  23%|██▎       | 276/1200 [00:03<00:16, 56.04draws/s]
# Sampling 2 chains:  24%|██▎       | 282/1200 [00:04<00:19, 47.48draws/s]
# Sampling 2 chains:  24%|██▍       | 288/1200 [00:04<00:18, 49.48draws/s]
# Sampling 2 chains:  24%|██▍       | 294/1200 [00:04<00:19, 47.13draws/s]
# Sampling 2 chains:  25%|██▍       | 299/1200 [00:04<00:20, 43.56draws/s]
# Sampling 2 chains:  25%|██▌       | 304/1200 [00:04<00:21, 42.38draws/s]
# Sampling 2 chains:  26%|██▌       | 310/1200 [00:04<00:19, 44.92draws/s]
# Sampling 2 chains:  26%|██▋       | 315/1200 [00:04<00:19, 44.60draws/s]
# Sampling 2 chains:  27%|██▋       | 320/1200 [00:05<01:16, 11.47draws/s]
# Sampling 2 chains:  27%|██▋       | 324/1200 [00:06<01:00, 14.59draws/s]
# Sampling 2 chains:  27%|██▋       | 328/1200 [00:06<00:53, 16.24draws/s]
# Sampling 2 chains:  28%|██▊       | 333/1200 [00:06<00:49, 17.59draws/s]
# Sampling 2 chains:  28%|██▊       | 341/1200 [00:06<00:37, 22.80draws/s]
# Sampling 2 chains:  29%|██▉       | 349/1200 [00:06<00:31, 27.09draws/s]
# Sampling 2 chains:  30%|██▉       | 354/1200 [00:06<00:27, 31.04draws/s]
# Sampling 2 chains:  30%|███       | 361/1200 [00:06<00:22, 36.81draws/s]
# Sampling 2 chains:  31%|███       | 368/1200 [00:07<00:19, 42.32draws/s]
# Sampling 2 chains:  31%|███▏      | 375/1200 [00:07<00:17, 47.28draws/s]
# Sampling 2 chains:  32%|███▏      | 386/1200 [00:07<00:15, 51.13draws/s]
# Sampling 2 chains:  33%|███▎      | 392/1200 [00:07<00:24, 32.57draws/s]
# Sampling 2 chains:  33%|███▎      | 397/1200 [00:09<01:56,  6.90draws/s]
# Sampling 2 chains:  33%|███▎      | 401/1200 [00:09<01:31,  8.76draws/s]
# Sampling 2 chains:  34%|███▍      | 405/1200 [00:10<01:30,  8.81draws/s]
# Sampling 2 chains:  34%|███▍      | 408/1200 [00:10<01:24,  9.34draws/s]
# Sampling 2 chains:  34%|███▍      | 411/1200 [00:10<01:15, 10.43draws/s]
# Sampling 2 chains:  34%|███▍      | 413/1200 [00:11<01:16, 10.22draws/s]
# Sampling 2 chains:  35%|███▍      | 415/1200 [00:11<01:09, 11.34draws/s]
# Sampling 2 chains:  35%|███▍      | 417/1200 [00:11<01:08, 11.50draws/s]
# Sampling 2 chains:  35%|███▍      | 419/1200 [00:11<01:00, 12.90draws/s]
# Sampling 2 chains:  35%|███▌      | 422/1200 [00:11<00:51, 15.05draws/s]
# Sampling 2 chains:  35%|███▌      | 424/1200 [00:11<00:54, 14.20draws/s]
# Sampling 2 chains:  36%|███▌      | 426/1200 [00:11<00:50, 15.39draws/s]
# Sampling 2 chains:  36%|███▌      | 428/1200 [00:12<00:58, 13.27draws/s]
# Sampling 2 chains:  36%|███▌      | 431/1200 [00:12<00:54, 14.21draws/s]
# Sampling 2 chains:  36%|███▌      | 434/1200 [00:12<00:58, 13.05draws/s]
# Sampling 2 chains:  36%|███▋      | 437/1200 [00:12<01:05, 11.72draws/s]
# Sampling 2 chains:  37%|███▋      | 440/1200 [00:12<00:55, 13.60draws/s]
# Sampling 2 chains:  37%|███▋      | 442/1200 [00:13<00:51, 14.66draws/s]
# Sampling 2 chains:  37%|███▋      | 445/1200 [00:13<00:44, 16.99draws/s]
# Sampling 2 chains:  37%|███▋      | 447/1200 [00:13<00:49, 15.10draws/s]
# Sampling 2 chains:  37%|███▋      | 449/1200 [00:13<00:50, 14.79draws/s]
# Sampling 2 chains:  38%|███▊      | 453/1200 [00:13<01:02, 12.00draws/s]
# Sampling 2 chains:  38%|███▊      | 455/1200 [00:14<01:09, 10.76draws/s]
# Sampling 2 chains:  38%|███▊      | 457/1200 [00:14<01:46,  6.99draws/s]
# Sampling 2 chains:  38%|███▊      | 458/1200 [00:14<01:38,  7.51draws/s]
# Sampling 2 chains:  38%|███▊      | 462/1200 [00:15<01:18,  9.38draws/s]
# Sampling 2 chains:  39%|███▉      | 465/1200 [00:15<01:13, 10.02draws/s]
# Sampling 2 chains:  39%|███▉      | 467/1200 [00:15<01:16,  9.52draws/s]
# Sampling 2 chains:  39%|███▉      | 470/1200 [00:17<03:13,  3.77draws/s]
# Sampling 2 chains:  39%|███▉      | 472/1200 [00:17<02:27,  4.95draws/s]
# Sampling 2 chains:  40%|███▉      | 474/1200 [00:17<01:59,  6.07draws/s]
# Sampling 2 chains:  40%|███▉      | 476/1200 [00:17<01:39,  7.31draws/s]
# Sampling 2 chains:  40%|███▉      | 478/1200 [00:19<04:51,  2.48draws/s]
# Sampling 2 chains:  40%|████      | 480/1200 [00:20<03:48,  3.15draws/s]
# Sampling 2 chains:  40%|████      | 481/1200 [00:20<03:25,  3.51draws/s]
# Sampling 2 chains:  40%|████      | 485/1200 [00:20<02:30,  4.75draws/s]
# Sampling 2 chains:  41%|████      | 487/1200 [00:20<01:57,  6.06draws/s]
# Sampling 2 chains:  41%|████      | 489/1200 [00:20<01:38,  7.21draws/s]
# Sampling 2 chains:  41%|████      | 491/1200 [00:21<02:42,  4.36draws/s]
# Sampling 2 chains:  41%|████      | 493/1200 [00:22<03:56,  2.99draws/s]
# Sampling 2 chains:  41%|████▏     | 495/1200 [00:22<03:01,  3.87draws/s]
# Sampling 2 chains:  42%|████▏     | 498/1200 [00:23<02:26,  4.81draws/s]
# Sampling 2 chains:  42%|████▏     | 501/1200 [00:23<01:50,  6.33draws/s]
# Sampling 2 chains:  42%|████▏     | 503/1200 [00:23<01:47,  6.46draws/s]
# Sampling 2 chains:  42%|████▏     | 505/1200 [00:23<01:42,  6.81draws/s]
# Sampling 2 chains:  42%|████▏     | 507/1200 [00:26<06:12,  1.86draws/s]
# Sampling 2 chains:  42%|████▏     | 508/1200 [00:27<08:00,  1.44draws/s]
# Sampling 2 chains:  42%|████▏     | 509/1200 [00:30<13:05,  1.14s/draws]
# Sampling 2 chains:  42%|████▎     | 510/1200 [00:33<22:40,  1.97s/draws]
# Sampling 2 chains:  43%|████▎     | 511/1200 [00:34<16:13,  1.41s/draws]
# Sampling 2 chains:  43%|████▎     | 512/1200 [00:35<14:51,  1.30s/draws]
# Sampling 2 chains:  43%|████▎     | 513/1200 [00:35<10:57,  1.05draws/s]
# Sampling 2 chains:  43%|████▎     | 514/1200 [00:36<10:54,  1.05draws/s]
# Sampling 2 chains:  43%|████▎     | 515/1200 [00:37<11:08,  1.02draws/s]
# Sampling 2 chains:  43%|████▎     | 517/1200 [00:37<08:00,  1.42draws/s]
# Sampling 2 chains:  43%|████▎     | 518/1200 [00:42<23:40,  2.08s/draws]
# Sampling 2 chains:  43%|████▎     | 521/1200 [00:42<16:39,  1.47s/draws]
# Sampling 2 chains:  44%|████▎     | 523/1200 [00:43<13:24,  1.19s/draws]
# Sampling 2 chains:  44%|████▎     | 524/1200 [00:43<09:45,  1.15draws/s]
# Sampling 2 chains:  44%|████▍     | 525/1200 [00:44<10:07,  1.11draws/s]
# Sampling 2 chains:  44%|████▍     | 526/1200 [00:48<18:09,  1.62s/draws]
# Sampling 2 chains:  44%|████▍     | 527/1200 [00:49<15:30,  1.38s/draws]
# Sampling 2 chains:  44%|████▍     | 528/1200 [00:54<29:05,  2.60s/draws]
# Sampling 2 chains:  44%|████▍     | 529/1200 [00:55<23:16,  2.08s/draws]
# Sampling 2 chains:  44%|████▍     | 532/1200 [00:55<16:28,  1.48s/draws]
# Sampling 2 chains:  44%|████▍     | 533/1200 [00:55<11:53,  1.07s/draws]
# Sampling 2 chains:  44%|████▍     | 534/1200 [00:56<09:34,  1.16draws/s]
# Sampling 2 chains:  45%|████▍     | 536/1200 [00:56<07:23,  1.50draws/s]
# Sampling 2 chains:  45%|████▍     | 537/1200 [00:57<06:56,  1.59draws/s]
# Sampling 2 chains:  45%|████▍     | 538/1200 [00:57<05:18,  2.08draws/s]
# Sampling 2 chains:  45%|████▍     | 539/1200 [00:57<05:27,  2.02draws/s]
# Sampling 2 chains:  45%|████▌     | 541/1200 [00:57<03:59,  2.76draws/s]
# Sampling 2 chains:  45%|████▌     | 542/1200 [00:59<08:16,  1.33draws/s]
# Sampling 2 chains:  45%|████▌     | 543/1200 [00:59<07:21,  1.49draws/s]
# Sampling 2 chains:  46%|████▌     | 546/1200 [01:00<05:15,  2.07draws/s]
# Sampling 2 chains:  46%|████▌     | 548/1200 [01:01<06:33,  1.65draws/s]
# Sampling 2 chains:  46%|████▌     | 551/1200 [01:02<04:42,  2.30draws/s]
# Sampling 2 chains:  46%|████▌     | 553/1200 [01:02<03:27,  3.12draws/s]
# Sampling 2 chains:  46%|████▋     | 555/1200 [01:02<02:34,  4.18draws/s]
# Sampling 2 chains:  47%|████▋     | 559/1200 [01:02<01:52,  5.72draws/s]
# Sampling 2 chains:  47%|████▋     | 562/1200 [01:02<01:30,  7.04draws/s]
# Sampling 2 chains:  47%|████▋     | 565/1200 [01:02<01:14,  8.57draws/s]
# Sampling 2 chains:  47%|████▋     | 567/1200 [01:02<01:14,  8.54draws/s]
# Sampling 2 chains:  48%|████▊     | 570/1200 [01:03<01:00, 10.35draws/s]
# Sampling 2 chains:  48%|████▊     | 572/1200 [01:03<00:52, 12.05draws/s]
# Sampling 2 chains:  48%|████▊     | 575/1200 [01:03<00:51, 12.22draws/s]
# Sampling 2 chains:  48%|████▊     | 578/1200 [01:04<01:29,  6.97draws/s]
# Sampling 2 chains:  48%|████▊     | 580/1200 [01:05<02:25,  4.26draws/s]
# Sampling 2 chains:  48%|████▊     | 581/1200 [01:05<02:01,  5.10draws/s]
# Sampling 2 chains:  49%|████▊     | 584/1200 [01:05<01:32,  6.64draws/s]
# Sampling 2 chains:  49%|████▉     | 587/1200 [01:08<04:45,  2.15draws/s]
# Sampling 2 chains:  49%|████▉     | 590/1200 [01:09<03:25,  2.96draws/s]
# Sampling 2 chains:  50%|████▉     | 594/1200 [01:09<02:27,  4.10draws/s]
# Sampling 2 chains:  50%|████▉     | 598/1200 [01:09<01:47,  5.60draws/s]
# Sampling 2 chains:  50%|█████     | 604/1200 [01:09<01:17,  7.69draws/s]
# Sampling 2 chains:  51%|█████     | 609/1200 [01:09<00:57, 10.28draws/s]
# Sampling 2 chains:  51%|█████     | 614/1200 [01:09<00:45, 12.74draws/s]
# Sampling 2 chains:  52%|█████▏    | 618/1200 [01:10<00:47, 12.17draws/s]
# Sampling 2 chains:  52%|█████▏    | 621/1200 [01:10<00:49, 11.74draws/s]
# Sampling 2 chains:  52%|█████▏    | 624/1200 [01:10<00:44, 12.98draws/s]
# Sampling 2 chains:  52%|█████▏    | 627/1200 [01:10<00:46, 12.28draws/s]
# Sampling 2 chains:  52%|█████▏    | 629/1200 [01:10<00:49, 11.48draws/s]
# Sampling 2 chains:  53%|█████▎    | 631/1200 [01:11<00:55, 10.26draws/s]
# Sampling 2 chains:  53%|█████▎    | 633/1200 [01:11<00:55, 10.26draws/s]
# Sampling 2 chains:  53%|█████▎    | 635/1200 [01:11<00:55, 10.17draws/s]
# Sampling 2 chains:  53%|█████▎    | 637/1200 [01:11<00:47, 11.84draws/s]
# Sampling 2 chains:  53%|█████▎    | 639/1200 [01:11<00:43, 12.84draws/s]
# Sampling 2 chains:  53%|█████▎    | 641/1200 [01:12<00:43, 12.98draws/s]
# Sampling 2 chains:  54%|█████▎    | 644/1200 [01:12<00:40, 13.81draws/s]
# Sampling 2 chains:  54%|█████▍    | 646/1200 [01:12<00:43, 12.62draws/s]
# Sampling 2 chains:  54%|█████▍    | 649/1200 [01:12<00:41, 13.31draws/s]
# Sampling 2 chains:  54%|█████▍    | 651/1200 [01:12<00:45, 12.19draws/s]
# Sampling 2 chains:  55%|█████▍    | 654/1200 [01:12<00:40, 13.50draws/s]
# Sampling 2 chains:  55%|█████▍    | 656/1200 [01:13<00:46, 11.82draws/s]
# Sampling 2 chains:  55%|█████▍    | 658/1200 [01:13<00:50, 10.78draws/s]
# Sampling 2 chains:  55%|█████▌    | 660/1200 [01:13<00:55,  9.65draws/s]
# Sampling 2 chains:  55%|█████▌    | 662/1200 [01:13<00:48, 11.18draws/s]
# Sampling 2 chains:  55%|█████▌    | 664/1200 [01:13<00:51, 10.51draws/s]
# Sampling 2 chains:  56%|█████▌    | 666/1200 [01:14<00:49, 10.70draws/s]
# Sampling 2 chains:  56%|█████▌    | 668/1200 [01:14<00:48, 11.07draws/s]
# Sampling 2 chains:  56%|█████▌    | 670/1200 [01:14<00:56,  9.32draws/s]
# Sampling 2 chains:  56%|█████▌    | 672/1200 [01:14<00:54,  9.61draws/s]
# Sampling 2 chains:  56%|█████▌    | 674/1200 [01:15<00:54,  9.63draws/s]
# Sampling 2 chains:  56%|█████▋    | 676/1200 [01:15<00:47, 11.11draws/s]
# Sampling 2 chains:  57%|█████▋    | 679/1200 [01:15<00:40, 12.77draws/s]
# Sampling 2 chains:  57%|█████▋    | 681/1200 [01:15<00:41, 12.40draws/s]
# Sampling 2 chains:  57%|█████▋    | 683/1200 [01:15<00:42, 12.06draws/s]
# Sampling 2 chains:  57%|█████▋    | 685/1200 [01:15<00:40, 12.57draws/s]
# Sampling 2 chains:  57%|█████▋    | 687/1200 [01:15<00:36, 14.14draws/s]
# Sampling 2 chains:  57%|█████▋    | 689/1200 [01:16<00:36, 13.87draws/s]
# Sampling 2 chains:  58%|█████▊    | 692/1200 [01:16<00:33, 15.38draws/s]
# Sampling 2 chains:  58%|█████▊    | 695/1200 [01:16<00:31, 15.90draws/s]
# Sampling 2 chains:  58%|█████▊    | 697/1200 [01:16<00:33, 15.19draws/s]
# Sampling 2 chains:  58%|█████▊    | 700/1200 [01:16<00:30, 16.50draws/s]
# Sampling 2 chains:  58%|█████▊    | 702/1200 [01:17<00:53,  9.36draws/s]
# Sampling 2 chains:  59%|█████▊    | 704/1200 [01:17<01:04,  7.65draws/s]
# Sampling 2 chains:  59%|█████▉    | 706/1200 [01:17<00:56,  8.69draws/s]
# Sampling 2 chains:  59%|█████▉    | 708/1200 [01:18<01:14,  6.63draws/s]
# Sampling 2 chains:  59%|█████▉    | 710/1200 [01:18<01:02,  7.86draws/s]
# Sampling 2 chains:  59%|█████▉    | 712/1200 [01:18<01:03,  7.73draws/s]
# Sampling 2 chains:  60%|█████▉    | 714/1200 [01:18<00:54,  8.90draws/s]
# Sampling 2 chains:  60%|█████▉    | 716/1200 [01:18<00:52,  9.16draws/s]
# Sampling 2 chains:  60%|█████▉    | 718/1200 [01:18<00:46, 10.31draws/s]
# Sampling 2 chains:  60%|██████    | 720/1200 [01:19<00:57,  8.42draws/s]
# Sampling 2 chains:  60%|██████    | 722/1200 [01:19<00:54,  8.83draws/s]
# Sampling 2 chains:  74%|███████▎  | 883/1200 [01:40<00:58,  5.43draws/s]
# Sampling 2 chains:  74%|███████▍  | 885/1200 [01:40<00:49,  6.34draws/s]
# Sampling 2 chains:  74%|███████▍  | 886/1200 [01:40<00:53,  5.86draws/s]
# Sampling 2 chains:  74%|███████▍  | 888/1200 [01:40<00:43,  7.09draws/s]
# Sampling 2 chains:  74%|███████▍  | 890/1200 [01:41<00:41,  7.40draws/s]
# Sampling 2 chains:  74%|███████▍  | 891/1200 [01:41<00:53,  5.76draws/s]
# Sampling 2 chains:  74%|███████▍  | 892/1200 [01:41<00:55,  5.57draws/s]
# Sampling 2 chains:  74%|███████▍  | 894/1200 [01:41<00:43,  7.02draws/s]
# Sampling 2 chains:  75%|███████▍  | 896/1200 [01:42<00:46,  6.56draws/s]
# Sampling 2 chains:  75%|███████▍  | 897/1200 [01:42<00:50,  6.04draws/s]
# Sampling 2 chains:  75%|███████▍  | 898/1200 [01:42<00:52,  5.79draws/s]
# Sampling 2 chains:  75%|███████▍  | 899/1200 [01:42<00:53,  5.60draws/s]
# Sampling 2 chains:  75%|███████▌  | 901/1200 [01:42<00:50,  5.95draws/s]
# Sampling 2 chains:  75%|███████▌  | 903/1200 [01:43<00:47,  6.20draws/s]
# Sampling 2 chains:  75%|███████▌  | 904/1200 [01:46<06:03,  1.23s/draws]
# Sampling 2 chains:  75%|███████▌  | 905/1200 [01:51<11:30,  2.34s/draws]
# Sampling 2 chains:  76%|███████▌  | 906/1200 [01:56<15:13,  3.11s/draws]
# Sampling 2 chains:  76%|███████▌  | 907/1200 [01:56<10:55,  2.24s/draws]
# Sampling 2 chains:  76%|███████▌  | 908/1200 [01:57<07:51,  1.61s/draws]
# Sampling 2 chains:  76%|███████▌  | 909/1200 [02:02<12:36,  2.60s/draws]
# Sampling 2 chains:  76%|███████▌  | 910/1200 [02:06<15:59,  3.31s/draws]
# Sampling 2 chains:  76%|███████▌  | 911/1200 [02:11<18:21,  3.81s/draws]
# Sampling 2 chains:  76%|███████▌  | 912/1200 [02:16<19:53,  4.14s/draws]
# Sampling 2 chains:  76%|███████▌  | 913/1200 [02:21<20:59,  4.39s/draws]
# Sampling 2 chains:  76%|███████▌  | 914/1200 [02:26<21:52,  4.59s/draws]
# Sampling 2 chains:  76%|███████▋  | 916/1200 [02:27<15:22,  3.25s/draws]
# Sampling 2 chains:  76%|███████▋  | 917/1200 [02:27<11:42,  2.48s/draws]
# Sampling 2 chains:  77%|███████▋  | 919/1200 [02:33<12:04,  2.58s/draws]
# Sampling 2 chains:  77%|███████▋  | 920/1200 [02:38<16:11,  3.47s/draws]
# Sampling 2 chains:  77%|███████▋  | 921/1200 [02:43<18:00,  3.87s/draws]
# Sampling 2 chains:  77%|███████▋  | 922/1200 [02:43<12:47,  2.76s/draws]
# Sampling 2 chains:  77%|███████▋  | 924/1200 [02:44<09:02,  1.96s/draws]
# Sampling 2 chains:  77%|███████▋  | 925/1200 [02:47<10:33,  2.30s/draws]
# Sampling 2 chains:  77%|███████▋  | 926/1200 [02:49<11:04,  2.43s/draws]
