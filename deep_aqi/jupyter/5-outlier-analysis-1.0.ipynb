# %%
from os.path import join, basename, splitext
from glob import glob
from dask import dataframe as dd
from matplotlib import rcParams
import pandas as pd
import dask
from collections import Counter
import pickle
import numpy as np
from datetime import datetime


from deep_aqi import ROOT


pd.set_option('max_columns', 50)
pd.set_option('max_rows', 25)

# %% [raw]
# * Wind Speed - Knots | 1 knot = .5144 m/s
# * Wind Direction - Degrees
# * Pressure - Milibars | 1 mbar = 100 Pa
# * Temperature - Fahrenheit | T_c = (T_f - 32) * 5/9
# * Relative Humidity - Percentage

# %%
PROCESSED_DATA = join(ROOT, 'data', 'processed')
INTERIM_DATA = join(ROOT, 'data', 'interim')
RAW_DATA = join(ROOT, 'data', 'raw')

# %%
weather_path = join(INTERIM_DATA, 'combined-WEATHER.parquet')
df = dd.read_parquet(weather_path)

# %%
df.head()
# Out:
# /home/filip/miniconda3/envs/deep_aqi/lib/python3.6/site-packages/dask/dataframe/core.py:4347: UserWarning: Insufficient elements for `head`. 5 elements requested, only 2 elements available. Try passing larger `npartitions` to `head`.
#   warnings.warn(msg.format(n, len(r)))
#                  SiteCode           LocalDate  WindDir   WindSpeed  \
# 0   Nebraska_Douglas_19.0 2014-04-03 23:00:00    149.0  150.660964
# 1  Tennessee_Sevier_101.0 2015-02-21 11:00:00    183.0   94.090202
#
#    Temperature  Pressure  RelHum
# 0     2.222222   96780.0    95.0
# 1     2.222222   87100.0    84.0

# %%
df.describe().compute()
# Out:
#             WindDir     WindSpeed   Temperature      Pressure        RelHum
# count  4.889150e+06  4.889150e+06  4.889150e+06  4.889150e+06  4.889150e+06
# mean   1.940485e+02  9.013095e+00  1.241722e+01  9.588095e+04  6.407332e+01
# std    1.003657e+02  7.407070e+00  1.137627e+01  6.921313e+03  2.248000e+01
# min    0.000000e+00  0.000000e+00 -5.000000e+01  0.000000e+00  0.000000e+00
# 25%    1.184000e+02  3.693624e+00  4.111111e+00  9.308000e+04  4.800000e+01
# 50%    1.980000e+02  6.998445e+00  1.333333e+01  9.906000e+04  6.700000e+01
# 75%    2.820000e+02  1.205288e+01  2.111111e+01  1.004000e+05  8.240000e+01
# max    3.600000e+02  1.506610e+02  5.722222e+01  1.596950e+05  1.000000e+02

# %% [markdown]
# ### Wind Speed [m/s]

# %%
df[df.WindSpeed > 70].describe().compute()
# Out:
#            WindDir    WindSpeed  Temperature       Pressure       RelHum
# count  1118.000000  1118.000000  1118.000000    1118.000000  1118.000000
# mean     68.559571    83.637745     6.271368   96977.271914    65.030590
# std      75.083276     5.890211     6.123105    6072.597902    20.744798
# min       0.000000    70.178849   -12.888889   77110.000000    12.000000
# 25%      33.000000    84.370140     2.611111   98880.000000    53.500000
# 50%      33.000000    84.370140     6.388889   99815.000000    73.500000
# 75%      36.000000    84.564541    11.111111  100200.000000    85.000000
# max     360.000000   150.660964    25.833333  101700.000000    99.600000

# %%
df.loc[df.WindSpeed > 70, 'SiteCode'].value_counts().compute()
# Out:
# Alabama_Jefferson_23.0        888
# Tennessee_Sevier_101.0        129
# Wyoming_Sublette_99.0          35
# Wyoming_Sweetwater_200.0       11
# Wyoming_Sweetwater_300.0       10
# Maryland_Garrett_2.0           10
# Nevada_Clark_540.0              9
# Nebraska_Douglas_19.0           7
# North Dakota_Burke_4.0          6
# Ohio_Preble_1001.0              5
# New Mexico_Bernalillo_23.0      3
# New York_Monroe_1007.0          2
# Colorado_Rio Blanco_6.0         2
# Wisconsin_Dodge_1.0             1
# Name: SiteCode, dtype: int64

# %%
df.loc[(df.SiteCode == 'Alabama_Jefferson_23.0') & (df.WindSpeed > 70), 'LocalDate'].dt.year.value_counts().compute()
# Out:
# 2015    879
# 2014      8
# 2017      1
# Name: LocalDate, dtype: int64

# %%
df.loc[(df.SiteCode == 'Alabama_Jefferson_23.0') & (df.WindSpeed > 70) & (df.LocalDate.dt.year == 2015), 'LocalDate'].dt.month.value_counts().compute()
# Out:
# 1    647
# 2    232
# Name: LocalDate, dtype: int64

# %% [markdown]
# Reason - especially severe conditions in central alabama in 2015
# https://www.weather.gov/bmx/climo_2015review#part5

# %%
df.loc[df.WindSpeed > 92.5, 'SiteCode'].value_counts().compute()
# Out:
# Tennessee_Sevier_101.0    13
# Nebraska_Douglas_19.0      5
# Maryland_Garrett_2.0       5
# Ohio_Preble_1001.0         2
# Wisconsin_Dodge_1.0        1
# New York_Monroe_1007.0     1
# Nevada_Clark_540.0         1
# Name: SiteCode, dtype: int64

# %% [markdown]
# Excluding all wind speed values exceeding 92.5 m/s - low border of F4 hurricane; 28 rows

# %% [markdown]
# ### Pressure [Pa]

# %%
df[df.Pressure < 80000].describe().compute()
# Out:
#              WindDir      WindSpeed    Temperature       Pressure  \
# count  280525.000000  280525.000000  280525.000000  280525.000000
# mean      207.002035      14.861334       4.233203   78070.165155
# std        97.415866      11.015743      10.951103    1867.500179
# min         0.000000       0.000000     -36.388889       0.000000
# 25%       129.000000       6.804044      -3.333333   77680.000000
# 50%       229.000000      12.052877       3.611111   78795.000000
# 75%       283.000000      21.189736      12.222222   79370.000000
# max       360.000000      86.508554      33.888889   79990.000000
#
#               RelHum
# count  280525.000000
# mean       59.773673
# std        24.460226
# min         0.000000
# 25%        40.000000
# 50%        63.000000
# 75%        81.000000
# max       100.000000

# %% [raw]
# df.loc[df.Pressure < 80000, 'SiteCode'].value_counts().compute()

# %% [markdown]
# Very low pressure in Wymoing, not caused by error: http://www.wrds.uwyo.edu/sco/climateatlas/pressure.html
# Maybe values are a little too low, but I believe not completely wrong.

# %%
df[df.Pressure < 72500].compute()
# Out:
#                                               SiteCode           LocalDate  \
# 59090                         North Dakota_Cass_1004.0 2014-10-31 10:00:00
# 289123                            Wyoming_Fremont_99.0 2010-12-29 06:00:00
# 289125                            Wyoming_Fremont_99.0 2010-12-29 16:00:00
# 289126                            Wyoming_Fremont_99.0 2010-12-30 01:00:00
# 404217                 North Carolina_Mecklenburg_41.0 2011-09-03 02:00:00
# 404218                 North Carolina_Mecklenburg_41.0 2011-09-03 03:00:00
# 524331  District Of Columbia_District of Columbia_43.0 2015-06-10 04:00:00
# 289211                            Wyoming_Fremont_99.0 2010-12-29 22:00:00
# 401324                      New Mexico_Bernalillo_23.0 2011-09-26 17:00:00
# 524557  District Of Columbia_District of Columbia_43.0 2015-06-20 00:00:00
# 524559  District Of Columbia_District of Columbia_43.0 2015-06-20 07:00:00
# 289360                            Wyoming_Fremont_99.0 2010-12-29 12:00:00
# ...                                                ...                 ...
# 253519                             Idaho_Shoshone_17.0 2010-11-24 17:00:00
# 289347                            Wyoming_Fremont_99.0 2010-12-29 15:00:00
# 289348                            Wyoming_Fremont_99.0 2010-12-29 20:00:00
# 398430                              Nevada_Clark_540.0 2011-07-15 07:00:00
# 432387                          California_Inyo_1018.0 2013-07-21 18:00:00
# 525461  District Of Columbia_District of Columbia_43.0 2015-05-29 05:00:00
# 525463  District Of Columbia_District of Columbia_43.0 2015-05-29 15:00:00
# 525479  District Of Columbia_District of Columbia_43.0 2015-06-06 19:00:00
# 525500  District Of Columbia_District of Columbia_43.0 2015-06-13 00:00:00
# 525518  District Of Columbia_District of Columbia_43.0 2015-06-19 14:00:00
# 525541  District Of Columbia_District of Columbia_43.0 2015-06-24 20:00:00
# 525545  District Of Columbia_District of Columbia_43.0 2015-06-26 00:00:00
#
#         WindDir  WindSpeed  Temperature  Pressure  RelHum
# 59090     131.0   7.776050    -2.222222   24130.0    76.0
# 289123    235.6  42.962675    -6.666667   72470.0    91.0
# 289125    225.2  22.939347    -5.000000   72230.0    94.0
# 289126      5.6  23.716952    -9.444444   72400.0    91.0
# 404217    313.0   0.972006    21.666667       0.0   100.0
# 404218    308.0   0.583204    21.111111       0.0   100.0
# 524331    331.0   8.553655    12.722222   52875.0    65.3
# 289211    296.4   4.471229    -5.000000   72330.0    96.0
# 401324    271.2  11.080871     9.722222   72400.0     6.0
# 524557    291.0   7.970451    27.416667   50415.0    75.0
# 524559     77.0   4.471229    13.444444   52380.0    73.4
# 289360    231.3  20.412131    -5.000000   72370.0    92.0
# ...         ...        ...          ...       ...     ...
# 253519    107.7   1.555210   -12.111111   71500.0    83.7
# 289347    224.8  20.800933    -5.555556   72270.0    94.0
# 289348    220.3  10.108865    -5.000000   72330.0    98.0
# 398430      0.0   0.000000   -17.777778       0.0     0.0
# 432387    163.0  21.772939    32.222222   50000.0    22.0
# 525461     53.0  13.413686    12.416667   53290.0    74.2
# 525463    151.0   8.359253    17.166667   53090.0    57.1
# 525479     96.0  10.497667    13.611111   52930.0    53.9
# 525500    298.0   6.220840    29.138889   50280.0    73.4
# 525518    304.0  15.163297    15.444444   52310.0    55.0
# 525541     99.0   3.693624    14.277778   52580.0    42.0
# 525545     74.0   9.914463    19.388889   50290.0    86.0
#
# [54 rows x 7 columns]

# %% [markdown]
# Drop pressure values lower than 7250 hPa, most likely measurement errors.

# %% [markdown]
# ### Temperature [C]

# %%
df[df.Temperature < -35].compute()
# Out:
#                         SiteCode           LocalDate  WindDir  WindSpeed  \
# 50500        Nevada_Clark_2002.0 2014-11-17 13:00:00     59.0   2.916019
# 166895     Wyoming_Sublette_99.0 2017-01-06 05:00:00     48.0   1.166407
# 166896     Wyoming_Sublette_99.0 2017-01-06 06:00:00    263.0   0.777605
# 551523  Michigan_Schoolcraft_1.0 2015-02-20 04:00:00     50.0   3.304821
# 166914     Wyoming_Sublette_99.0 2017-01-06 07:00:00    211.0   2.721617
# 168015  Wyoming_Sweetwater_200.0 2017-01-06 02:00:00    123.0   1.166407
# 551701  Michigan_Schoolcraft_1.0 2015-02-20 06:00:00     58.0   3.304821
# 50347        Nevada_Clark_2002.0 2014-11-13 13:00:00     48.0   3.304821
# 552743  Michigan_Schoolcraft_1.0 2015-02-20 05:00:00     54.0   3.304821
# 166786     Wyoming_Sublette_99.0 2017-01-06 02:00:00    270.0   2.332815
# 167920  Wyoming_Sweetwater_200.0 2017-01-06 03:00:00    142.0   2.332815
# 166987     Wyoming_Sublette_99.0 2017-01-06 08:00:00     40.0   3.693624
# 166678     Wyoming_Sublette_99.0 2017-01-06 01:00:00    262.0   3.693624
# 166679     Wyoming_Sublette_99.0 2017-01-06 04:00:00    327.0   2.721617
# 168879  Wyoming_Sweetwater_300.0 2017-01-06 05:00:00    323.0   6.415241
# 168880  Wyoming_Sweetwater_300.0 2017-01-06 06:00:00    316.0   5.637636
# 427018     Wyoming_Sublette_99.0 2011-02-02 07:00:00    283.0   2.721617
# 167726  Wyoming_Sweetwater_200.0 2017-01-06 04:00:00    130.0   4.082426
#
#         Temperature  Pressure  RelHum
# 50500    -37.222222   95800.0    42.0
# 166895   -35.555556   77940.0    63.0
# 166896   -35.277778   77970.0    63.0
# 551523   -36.111111   99900.0    72.0
# 166914   -36.388889   78030.0    62.0
# 168015   -35.555556   79020.0    69.0
# 551701   -36.111111   99700.0    72.0
# 50347    -50.000000   94500.0     8.0
# 552743   -36.111111   99700.0    71.0
# 166786   -35.277778   77880.0    64.0
# 167920   -36.111111   79030.0    69.0
# 166987   -36.111111   78110.0    62.0
# 166678   -35.277778   77850.0    64.0
# 166679   -35.555556   77930.0    64.0
# 168879   -35.555556   80210.0    67.0
# 168880   -35.555556   80250.0    67.0
# 427018   -35.277778   78660.0    62.0
# 167726   -35.833333   79070.0    69.0

# %%
temp = df.loc[(df.SiteCode == 'Nevada_Clark_2002.0') & (df.LocalDate >= datetime(2014, 11, 13)) & (df.LocalDate <= datetime(2014, 11, 18)), :].compute()
temp.sort_values(by='LocalDate')
# Out:
#                   SiteCode           LocalDate  WindDir  WindSpeed  \
# 50483  Nevada_Clark_2002.0 2014-11-13 00:00:00    241.0   0.583204
# 50428  Nevada_Clark_2002.0 2014-11-13 01:00:00     62.0   2.332815
# 50452  Nevada_Clark_2002.0 2014-11-13 02:00:00     49.0   4.665630
# 50484  Nevada_Clark_2002.0 2014-11-13 03:00:00     35.0   4.276827
# 50453  Nevada_Clark_2002.0 2014-11-13 04:00:00     41.0   4.276827
# 50454  Nevada_Clark_2002.0 2014-11-13 05:00:00     47.0   4.665630
# 50455  Nevada_Clark_2002.0 2014-11-13 06:00:00     42.0   4.276827
# 50498  Nevada_Clark_2002.0 2014-11-13 07:00:00     52.0   5.248834
# 50499  Nevada_Clark_2002.0 2014-11-13 08:00:00     85.0   5.637636
# 50347  Nevada_Clark_2002.0 2014-11-13 13:00:00     48.0   3.304821
# 50464  Nevada_Clark_2002.0 2014-11-17 10:00:00     31.0   2.138414
# 50348  Nevada_Clark_2002.0 2014-11-17 12:00:00    119.0   2.527216
# 50500  Nevada_Clark_2002.0 2014-11-17 13:00:00     59.0   2.916019
# 50332  Nevada_Clark_2002.0 2014-11-17 14:00:00     65.0   3.693624
# 50485  Nevada_Clark_2002.0 2014-11-17 15:00:00    147.0   1.749611
# 50349  Nevada_Clark_2002.0 2014-11-17 16:00:00    230.0   2.721617
# 50333  Nevada_Clark_2002.0 2014-11-17 17:00:00    276.0   3.693624
# 50561  Nevada_Clark_2002.0 2014-11-17 18:00:00    293.0   5.443235
# 50465  Nevada_Clark_2002.0 2014-11-17 19:00:00    332.0   8.164852
# 50334  Nevada_Clark_2002.0 2014-11-17 20:00:00    300.0   2.916019
# 50456  Nevada_Clark_2002.0 2014-11-17 21:00:00    308.0   3.110420
# 50429  Nevada_Clark_2002.0 2014-11-17 22:00:00    320.0   2.916019
# 50501  Nevada_Clark_2002.0 2014-11-17 23:00:00    286.0   5.248834
# 50502  Nevada_Clark_2002.0 2014-11-18 00:00:00    335.0   3.304821
#
#        Temperature  Pressure  RelHum
# 50483    13.333333   94700.0    32.0
# 50428    13.888889   94700.0    34.0
# 50452    13.888889   94700.0    26.0
# 50484    15.000000   94700.0    27.0
# 50453    14.444444   94700.0    27.0
# 50454    13.333333   94800.0    25.0
# 50455    13.333333   94800.0    28.0
# 50498    14.444444   94800.0    26.0
# 50499    16.666667   94900.0    24.0
# 50347   -50.000000   94500.0     8.0
# 50464   -12.222222   95900.0    39.0
# 50348    13.888889   95900.0    13.0
# 50500   -37.222222   95800.0    42.0
# 50332    14.444444   95800.0    16.0
# 50485    15.000000   95700.0    15.0
# 50349    14.444444   95700.0    18.0
# 50333    12.777778   95700.0    21.0
# 50561    11.666667   95700.0    24.0
# 50465    10.555556   95800.0    28.0
# 50334     8.888889   95800.0    33.0
# 50456     7.777778   95800.0    35.0
# 50429     7.222222   95900.0    37.0
# 50501     6.111111   95900.0    37.0
# 50502     6.111111   95900.0    41.0

# %% [markdown]
# Sign of temperature is switching, most likely an error.
#
# Check how common are such errors.

# %%
temps = df.loc[:, ['SiteCode', 'LocalDate', 'Temperature']]

# %%
sites = temps.SiteCode.unique().compute().tolist()
len(sites)
# Out:
# 99

# %%
tables_to_investigate = []
for site in sites:
    a = temps.loc[temps.SiteCode == site, :].compute().sort_values(by='LocalDate')
    b = a['Temperature'].shift(periods=1)
    a['ShiftedTemperature'] = b
    a['absolute_difference'] = (a.Temperature - a.ShiftedTemperature).abs()
    thresh = a.loc[a.absolute_difference > 5]
    tables_to_investigate.append(thresh)
    
result = pd.concat(tables_to_investigate)

# %%
result.SiteCode.value_counts()
# Out:
# California_Santa Barbara_2011.0    684
# New York_Herkimer_5.0              521
# Nevada_Washoe_1026.0               485
# Wyoming_Teton_8.0                  450
# Colorado_Rio Blanco_5.0            388
# Louisiana_East Baton Rouge_13.0    364
# Wyoming_Natrona_2601.0             326
# Wyoming_Sweetwater_200.0           310
# Wyoming_Laramie_100.0              290
# Wyoming_Sublette_99.0              239
# Iowa_Linn_40.0                     232
# Colorado_Rio Blanco_6.0            202
#                                   ...
# California_Madera_2010.0            32
# Michigan_Wayne_19.0                 31
# Nevada_Clark_2002.0                 28
# Michigan_Wayne_1.0                  27
# Maryland_Dorchester_4.0             24
# Nevada_Clark_75.0                   23
# New Jersey_Essex_3.0                23
# Michigan_Kent_20.0                  19
# Oregon_Multnomah_80.0               14
# Massachusetts_Suffolk_42.0          10
# Washington_King_80.0                 3
# Hawaii_Hawaii_7.0                    3
# Name: SiteCode, Length: 99, dtype: int64

# %%
result.loc[result.SiteCode == 'California_Santa Barbara_2011.0', 'LocalDate'].dt.hour.value_counts()
# Out:
# 8     255
# 9     197
# 7     122
# 10     28
# 17     22
# 6      14
# 18     14
# 23      4
# 21      4
# 11      3
# 1       3
# 12      3
# 22      2
# 15      2
# 2       2
# 20      2
# 0       2
# 13      1
# 14      1
# 16      1
# 19      1
# 5       1
# Name: LocalDate, dtype: int64

# %%
before_temp = result.loc[result.SiteCode == 'California_Santa Barbara_2011.0', 'ShiftedTemperature']
after_temp = result.loc[result.SiteCode == 'California_Santa Barbara_2011.0', 'Temperature']

(before_temp < after_temp).sum() / len(before_temp < after_temp)
# Out:
# 0.9283625730994152

# %% [markdown]
# 'California_Santa Barbara_2011.0' drastic temp shift seems to be sunrise
#
# https://www.timeanddate.com/sun/usa/santa-barbara

# %%
result[result.SiteCode == 'Nevada_Clark_2002.0']
# Out:
#                    SiteCode           LocalDate  Temperature  \
# 207544  Nevada_Clark_2002.0 2012-01-06 09:00:00    10.555556
# 207694  Nevada_Clark_2002.0 2012-01-07 09:00:00    14.444444
# 207832  Nevada_Clark_2002.0 2012-03-07 04:00:00     3.888889
# 207777  Nevada_Clark_2002.0 2012-03-25 21:00:00    13.333333
# 208216  Nevada_Clark_2002.0 2012-08-10 09:00:00    36.666667
# 208058  Nevada_Clark_2002.0 2012-10-02 13:00:00    35.000000
# 480210  Nevada_Clark_2002.0 2013-04-08 07:00:00    10.000000
# 480662  Nevada_Clark_2002.0 2013-07-19 19:00:00    26.111111
# 480665  Nevada_Clark_2002.0 2013-07-20 22:00:00    25.555556
# 480622  Nevada_Clark_2002.0 2013-08-18 15:00:00    30.000000
# 479822  Nevada_Clark_2002.0 2013-09-09 16:00:00    26.666667
# 479844  Nevada_Clark_2002.0 2013-09-17 08:00:00    30.555556
# ...                     ...                 ...          ...
# 50430   Nevada_Clark_2002.0 2014-10-30 08:00:00    21.666667
# 50347   Nevada_Clark_2002.0 2014-11-13 13:00:00   -50.000000
# 50464   Nevada_Clark_2002.0 2014-11-17 10:00:00   -12.222222
# 50348   Nevada_Clark_2002.0 2014-11-17 12:00:00    13.888889
# 50500   Nevada_Clark_2002.0 2014-11-17 13:00:00   -37.222222
# 50332   Nevada_Clark_2002.0 2014-11-17 14:00:00    14.444444
# 571151  Nevada_Clark_2002.0 2015-04-25 16:00:00    13.333333
# 572704  Nevada_Clark_2002.0 2015-07-06 18:00:00    25.555556
# 572736  Nevada_Clark_2002.0 2015-08-11 11:00:00    37.222222
# 572959  Nevada_Clark_2002.0 2015-10-12 12:00:00    32.222222
# 573040  Nevada_Clark_2002.0 2015-12-08 14:00:00    18.333333
# 573146  Nevada_Clark_2002.0 2015-12-25 00:00:00     4.444444
#
#         ShiftedTemperature  absolute_difference
# 207544            3.888889             6.666667
# 207694            8.333333             6.111111
# 207832           22.222222            18.333333
# 207777           18.888889             5.555556
# 208216           26.666667            10.000000
# 208058           28.888889             6.111111
# 480210           15.555556             5.555556
# 480662           41.111111            15.000000
# 480665           39.444444            13.888889
# 480622           37.777778             7.777778
# 479822           32.777778             6.111111
# 479844           25.000000             5.555556
# ...                    ...                  ...
# 50430            27.777778             6.111111
# 50347            16.666667            66.666667
# 50464           -50.000000            37.777778
# 50348           -12.222222            26.111111
# 50500            13.888889            51.111111
# 50332           -37.222222            51.666667
# 571151           20.000000             6.666667
# 572704           33.888889             8.333333
# 572736           28.888889             8.333333
# 572959           22.777778             9.444444
# 573040            2.777778            15.555556
# 573146           10.555556             6.111111
#
# [28 rows x 5 columns]

# %%
result.loc[result.absolute_difference > 20, 'SiteCode'].value_counts()
# Out:
# Nevada_Clark_540.0                10
# Nevada_Clark_2002.0                5
# New Mexico_Bernalillo_23.0         3
# Iowa_Scott_15.0                    2
# Nevada_Washoe_1026.0               2
# Michigan_Wayne_1.0                 2
# Louisiana_East Baton Rouge_9.0     2
# Wyoming_Sweetwater_200.0           2
# Alabama_Jefferson_23.0             2
# Texas_Harris_416.0                 1
# Idaho_Nez Perce_12.0               1
# Missouri_Jefferson_19.0            1
# Ohio_Hamilton_40.0                 1
# Oregon_Klamath_4.0                 1
# Michigan_Wayne_19.0                1
# California_Kern_6001.0             1
# Name: SiteCode, dtype: int64

# %% [markdown]
# Conclusion, there is something definitely wrong with temperature measurements in Nevada Clark 2002 and 540.
#
# Solution, drop faulty months of data from these 2 sites.

# %%
cond = (result.absolute_difference > 20) & (result.SiteCode.isin(['Nevada_Clark_540.0', 'Nevada_Clark_2002.0']))
temp = result.loc[cond, ['SiteCode', 'LocalDate']]
temp.LocalDate = temp.LocalDate.dt.date
temp.drop_duplicates('LocalDate')
# Out:
#                    SiteCode   LocalDate
# 50347   Nevada_Clark_2002.0  2014-11-13
# 50464   Nevada_Clark_2002.0  2014-11-17
# 398501   Nevada_Clark_540.0  2011-04-14
# 398430   Nevada_Clark_540.0  2011-07-15
# 398585   Nevada_Clark_540.0  2011-09-01
# 399012   Nevada_Clark_540.0  2011-09-27
# 399021   Nevada_Clark_540.0  2011-09-29

# %% [markdown]
# to drop:
# * nov 2014
# * apr, jul, sep 2011

# %%
clark2002 = (weather.SiteCode == 'Nevada_Clark_2002.0') & (weather.LocalDate.dt.year == 2014) & (weather.LocalDate.dt.month == 11)
clark540 = (weather.SiteCode == 'Nevada_Clark_540.0') & (weather.LocalDate.dt.year == 2011) & (weather.LocalDate.dt.month.isin([4, 7, 9]))

# %%
weather =df

# %%
print(len(weather))
# Out:
# 4889068

# %%
clark2002 = (weather.SiteCode == 'Nevada_Clark_2002.0') & (weather.LocalDate.dt.year == 2014) & (weather.LocalDate.dt.month == 11)
clark540 = (weather.SiteCode == 'Nevada_Clark_540.0') & (weather.LocalDate.dt.year == 2011) & (weather.LocalDate.dt.month.isin([4, 7, 9]))
weather = weather.loc[~clark2002 & ~clark540, :]
print(len(weather))
# Out:
# 4886268

# %%
len(df)
# Out:
# 4889068
